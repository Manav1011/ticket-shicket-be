# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../src')))

# %%
from src.auth.password import hash_password, verify_password

# %%
print(await hash_password("Manav@1011"))
# Out:
# $2b$12$bk5n.xvEBtQMiswPzQODQuUuj.ABYvZCaKv9YasdzKWXgjj.oMtY6

# %%
import asyncio
from src.db.session import async_session
from src.apps.event.models import EventInterestModel

async def delete_all_event_interests():
    async with async_session() as session:
        await session.execute('DELETE FROM event_interests')
        await session.commit()

# %%
import hashlib


token_hash = hashlib.sha256("tqrlzarp".encode()).hexdigest()
token_hash
# Out:
# '7ddaeb75aff970580eeb830ae5e423bfc2e37cfecbde3a11a8b54ad5cececfba'
